# %%
import pandas as pd
df= pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")
df
# Out:
#          Unnamed: 0       Id       Name  Year Gender State  Count
# 0             11349    11350       Emma  2004      F    AK     62
# 1             11350    11351    Madison  2004      F    AK     48
# 2             11351    11352     Hannah  2004      F    AK     46
# 3             11352    11353      Grace  2004      F    AK     44
# 4             11353    11354      Emily  2004      F    AK     41
# 5             11354    11355    Abigail  2004      F    AK     37
# 6             11355    11356     Olivia  2004      F    AK     33
# 7             11356    11357   Isabella  2004      F    AK     30
# 8             11357    11358     Alyssa  2004      F    AK     29
# 9             11358    11359     Sophia  2004      F    AK     28
# 10            11359    11360     Alexis  2004      F    AK     27
# 11            11360    11361  Elizabeth  2004      F    AK     27
# 12            11361    11362     Hailey  2004      F    AK     27
# ...

# %%
#Remove unnamed columns
del df['Unnamed: 0']

# %%
df
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %%
#2. Show the distribution(as count) of male and female
df.Gender.value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
#2. Show the distribution(as proportion)of male and female
df.Gender.value_counts(normalize=True)
# Out:
# F    0.549832
# M    0.450168
# Name: Gender, dtype: float64

# %%
df.Name.value_counts()
# Out:
# Riley         1112
# Avery         1080
# Jordan        1073
# Peyton        1064
# Hayden        1049
# Taylor        1033
# Jayden        1031
# Alexis         984
# Payton         971
# Angel          962
# Dakota         962
# Logan          957
# Parker         947
# Morgan         945
# Cameron        944
# Ryan           901
# Skyler         895
# Dylan          895
# Reese          880
# Quinn          873
# Skylar         872
# Kayden         872
# Rowan          842
# Jaden          840
# Charlie        816
# Rylee          799
# Emerson        798
# Kendall        793
# Micah          788
# Jaiden         779
#               ...
# Phyllis          1
# Mayara           1
# Yanell           1
# Adeena           1
# Jenin            1
# Adonnis          1
# Yoceline         1
# Fender           1
# Vaden            1
# Madailein        1
# Jhayden          1
# Dhanya           1
# Kataleyah        1
# Assa             1
# Omran            1
# Sereena          1
# ...

# %%
#3.Show the top 5 most preferred names
df.Name.value_counts().head(5)
# Out:
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Name, dtype: int64

# %%
#4. What is the median name occurence in the dataset

df.Name.value_counts().median()
# Out:
# 8.0

# %%
#5.Distribution(as count) of male and female born count by states
df.groupby(['State']).Gender.value_counts())
# Out:
# State  Gender
# AK     M          2587
#        F          2404
# AL     F          9878
#        M          8419
# AR     F          7171
#        M          6475
# AZ     F         14518
#        M         10820
# CA     F         45144
#        M         31637
# CO     F         11424
#        M          9183
# CT     F          6575
#        M          5733
# DC     F          3053
#        M          3000
# DE     F          2549
#        M          2440
# FL     F         25781
#        M         20070
# GA     F         19385
#        M         15454
# HI     M          3546
#        F          3255
# IA     F          7131
#        M          6307
# ID     F          4918
#        M          4833
# IL     F         21268
#        M         16828
#                  ...
# OK     F          9519
#        M          8138
# OR     F          8604
#        M          7333
# PA     F         17480
#        M         14171
# RI     F          2558
#        M          2468
# ...

# %%
#5.Distribution(as proportions) of male and female born count by states
df.groupby(['State']).Gender.value_counts(normalize=True)
# Out:
# State  Gender
# AK     M         0.518333
#        F         0.481667
# AL     F         0.539870
#        M         0.460130
# AR     F         0.525502
#        M         0.474498
# AZ     F         0.572973
#        M         0.427027
# CA     F         0.587958
#        M         0.412042
# CO     F         0.554375
#        M         0.445625
# CT     F         0.534205
#        M         0.465795
# DC     F         0.504378
#        M         0.495622
# DE     F         0.510924
#        M         0.489076
# FL     F         0.562278
#        M         0.437722
# GA     F         0.556417
#        M         0.443583
# HI     M         0.521394
#        F         0.478606
# IA     F         0.530659
#        M         0.469341
# ID     F         0.504359
#        M         0.495641
# IL     F         0.558274
#        M         0.441726
#                    ...
# OK     F         0.539106
#        M         0.460894
# OR     F         0.539876
#        M         0.460124
# ...
